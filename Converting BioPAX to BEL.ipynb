# %% [markdown]
# # Converting BioPAX to BEL
#
# **Author:** [Charles Tapley Hoyt](https://github.com/cthoyt/)
#
# **Estimated Run Time:** 5 seconds
#
# This notebook shows how a [WikiPathways](https://www.wikipathways.org) entry, distributed as [BioPAX](http://www.biopax.org/), can be loaded into PyBEL using [INDRA](http://indra.readthedocs.io/en/latest/).

# %% [markdown]
# ## Imports

# %%
import pkg_resources
import sys
import os
import time
from urllib.request import urlretrieve

import indra.util.get_version
import jnius
import pybel
import pybel_tools
from pybel_tools.visualization import to_jupyter

# %% [markdown]
# ## Environment

# %%
# %%bash
# java -showversion 2>&1 | head -n 4
# Out:
# java version "1.8.0_152"
# Java(TM) SE Runtime Environment (build 1.8.0_152-b16)
# Java HotSpot(TM) 64-Bit Server VM (build 25.152-b16, mixed mode)

# %%
print(sys.version)
# Out:
# 3.6.3 (default, Oct  9 2017, 09:47:56)
# [GCC 4.2.1 Compatible Apple LLVM 9.0.0 (clang-900.0.37)]

# %%
print(time.asctime())
# Out:
# Fri Mar 16 15:35:30 2018

# %%
#os.environ['CLASSPATH'] = "~/dev/jars/*:~/dev/indra/indra/sources/biopax/jars/*"
os.environ['CLASSPATH']
# Out:
# '~/dev/indra/indra/sources/biopax/jars/paxtools.jar:~/dev/jars/*:'

# %% [markdown]
# ## Dependencies

# %%
pybel.utils.get_version()
# Out:
# '0.11.2-dev'

# %%
pybel_tools.utils.get_version()
# Out:
# '0.5.2-dev'

# %%
pkg_resources.get_distribution("pyjnius").version
# Out:
# '1.1.1'

# %%
indra.util.get_version.get_version()
# Out:
# "1.5.0-b'dcf2f45592f9c96b58622f42ba58ca342157488d'"

# %% [markdown]
# # Data
#
# The [apoptosis pathway](https://www.wikipathways.org/index.php/Pathway:WP254) is downloaded from WikiPathways to the current user's downloads folder.

# %%
apoptosis_url = 'https://www.wikipathways.org//wpi/wpi.php?action=downloadFile&type=owl&pwTitle=Pathway:WP254&oldid=95107'

# %%
apoptosis_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'WP254_95107.owl')

# %%
if not os.path.exists(apoptosis_path):
    urlretrieve(apoptosis_url, apoptosis_path)

# %% [markdown]
# # Conversion
#
# A file path is given to [`pybel.from_biopax`](http://pybel.readthedocs.io/en/latest/io.html#pybel.io.indra.from_biopax), which wraps `indra.sources.biopax.biopax_api.process_owl`.

# %%
# %%time

graph = pybel.from_biopax(apoptosis_path)
# Out:
# WARNING: [2018-03-16 15:35:30] indra/java_vm - Couldn't set memory limit for Java VM because the VM is already running.
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.PatternBox
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.ConBox
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.util.RelType
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.Type
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.ConversionSide
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.ConversionSide$Type
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.Participant
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.ModificationChangeConstraint
# ERROR: [2018-03-16 15:35:33] indra/biopax - Could not instantiate org.biopax.paxtools.pattern.constraint.ModificationChangeConstraint$Type
# ---------------------------------------------------------------------------
# JavaException                             Traceback (most recent call last)
# <ipython-input-13-36cbc7b280c9> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', '\ngraph = pybel.from_biopax(apoptosis_path)')
#
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /Users/cthoyt/dev/pybel/src/pybel/io/indra.py in from_biopax(path, name, version, description)
#     115     from indra.sources.biopax.biopax_api import process_owl
#     116
# --> 117     model = process_owl(path)
#     118
#     119     return from_indra_statements(
#
# /Users/cthoyt/dev/indra/indra/sources/biopax/biopax_api.py in process_owl(owl_filename)
#     157         A BiopaxProcessor containing the obtained BioPAX model in bp.model.
#     158     """
# --> 159     model = pcc.owl_to_model(owl_filename)
#     160     return process_model(model)
#     161
#
# /Users/cthoyt/dev/indra/indra/sources/biopax/pathway_commons_client.py in owl_to_model(fname)
#     134         A BioPAX model object (java object).
#     135     """
# --> 136     io_class = autoclass('org.biopax.paxtools.io.SimpleIOHandler')
#     137     io = io_class(autoclass('org.biopax.paxtools.model.BioPAXLevel').L3)
#     138
#
# /usr/local/lib/python3.6/site-packages/jnius/reflect.py in autoclass(clsname)
#     156
#     157     # c = Class.forName(clsname)
# --> 158     c = find_javaclass(clsname)
#     159     if c is None:
#     160         raise Exception('Java class {0} not found'.format(c))
#
# jnius/jnius_export_func.pxi in jnius.find_javaclass()
#
# JavaException: Class not found b'org/biopax/paxtools/io/SimpleIOHandler'

# %%
to_jupyter(graph)
