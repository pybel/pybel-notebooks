# %% [markdown]
# This notebook contains a code snippet that generats a pandas DataFrame containing the summary for a given knowledge assembly, split by a given annotation

# %%
import os
import sys
import time

import pandas as pd

import pybel
from pybel.constants import VERSION as PYBEL_VERSION
from pybel_tools import selection
from pybel_tools.summary import info_json, info_list
from pybel_tools.mutation import infer_central_dogma

# %%
print(sys.version)
# Out:
# 3.6.3 (default, Oct  9 2017, 09:47:56)
# [GCC 4.2.1 Compatible Apple LLVM 9.0.0 (clang-900.0.37)]

# %%
print(time.asctime())
# Out:
# Thu Jan 11 14:11:38 2018

# %%
print(PYBEL_VERSION)
# Out:
# 0.10.2-dev

# %%
bms_base = os.environ["BMS_BASE"]

# %% [markdown]
# In this example, we'll summarize the NeuroMMSig subgraphs in the Epilepsy Knowledge Assembly (Hoyt, et. al 2018).

# %%
graph = pybel.from_pickle(
    os.path.join(bms_base, "aetionomy", "epilepsy", "epilepsy.gpickle")
)
print(graph)
# Out:
# Epilepsy Knowledge Assembly v2.0.1

# %%
infer_central_dogma(graph)

# %%
subgraphs = selection.get_subgraphs_by_annotation(graph, "Subgraph")

len(subgraphs)
# Out:
# 32

# %%
def fix_columns(df_):
    for c in ["Authors", "Nodes", "Edges", "Citations", "Components"]:
        df_[c] = df_[c].astype(int)

# %% [markdown]
# Using the [`info_json`](http://pybel-tools.readthedocs.io/en/latest/summary.html#pybel_tools.summary.info_json) function, the nodes, edges, citations, authors, average degree, and network density of a graph are entered in a dictionary.

# %%
data = {
    subgraph_name.capitalize(): info_json(subgraph)
    for subgraph_name, subgraph in subgraphs.items()
}
df = pd.DataFrame(data).T
fix_columns(df)

df_total = pd.DataFrame({"Total": info_json(graph)}).T
del df_total["Compilation warnings"]
fix_columns(df_total)
df_total

df = pd.concat([df, df_total])
df
# Out:
#                                                     Authors  Average degree  \
# Adaptive immune system subgraph                           0        1.000000
# Adenosine signaling subgraph                              0        2.026316
# Apoptosis signaling subgraph                              0        2.206140
# Brain_derived neurotrophic factor signaling sub...        0        1.893333
# Calcium dependent subgraph                                0        2.625828
# Chromatin organization subgraph                           0        1.250000
# Energy metabolic subgraph                                 0        1.945055
# Estradiol metabolism                                      0        1.142857
# G-protein-mediated signaling                              0        1.794872
# Gaba subgraph                                             0        2.412214
# Glutamatergic subgraph                                    0        2.033058
# Hormone signaling subgraph                                0        2.031746
# Inflammatory response subgraph                            0        1.166667
# Innate immune system subgraph                             0        1.536585
# Interleukin signaling subgraph                            0        2.413043
# Long term synaptic depression                             0        2.015625
# Long term synaptic potentiation                           0        2.016000
# Mapk-erk subgraph                                         0        2.255591
# Metabolism                                                0        1.764706
# Mirna subgraph                                            0        0.800000
# Mossy fiber subgraph                                      0        1.736842
# Mtor signaling subgraph                                   0        2.024096
# Neurotransmitter release subgraph                         0        3.019928
# Notch signaling subgraph                                  0        1.952381
# Protein kinase signaling subgraph                         0        2.254642
# Protein metabolism                                        0        1.434109
# Reelin signaling subgraph                                 0        2.162393
# Regulation of actin cytoskeleton subgraph                 0        0.600000
# Serotonergic subgraph                                     0        3.229730
# Thyroid hormone signaling subgraph                        0        2.150943
# Transport related subgraph                                0        1.224490
# Wnt signaling subgraph                                    0        1.407407
# Total                                                     0        3.588557
#
#                                                     Citations  Components  \
# Adaptive immune system subgraph                             5           4
# Adenosine signaling subgraph                               15           3
# Apoptosis signaling subgraph                              115           5
# Brain_derived neurotrophic factor signaling sub...         29           1
# Calcium dependent subgraph                                 73           8
# Chromatin organization subgraph                             2           2
# Energy metabolic subgraph                                  24           4
# Estradiol metabolism                                        1           2
# G-protein-mediated signaling                               25           5
# Gaba subgraph                                              56           2
# Glutamatergic subgraph                                     32           5
# Hormone signaling subgraph                                 16           9
# Inflammatory response subgraph                             21           4
# Innate immune system subgraph                              18           8
# Interleukin signaling subgraph                             17           3
# Long term synaptic depression                              21           2
# Long term synaptic potentiation                            46           2
# Mapk-erk subgraph                                          68           5
# Metabolism                                                126          14
# Mirna subgraph                                              3           1
# Mossy fiber subgraph                                       14           2
# Mtor signaling subgraph                                    42           3
# Neurotransmitter release subgraph                         131           5
# Notch signaling subgraph                                   20           3
# Protein kinase signaling subgraph                          87           6
# Protein metabolism                                         44           8
# Reelin signaling subgraph                                  21           2
# Regulation of actin cytoskeleton subgraph                   2           2
# Serotonergic subgraph                                      18           2
# Thyroid hormone signaling subgraph                          9           2
# Transport related subgraph                                 25           7
# Wnt signaling subgraph                                     15           3
# Total                                                     638          16
#
#                                                     Edges  Network density  \
# Adaptive immune system subgraph                        12         0.090909
# Adenosine signaling subgraph                          154         0.027018
# Apoptosis signaling subgraph                          503         0.009719
# Brain_derived neurotrophic factor signaling sub...    142         0.025586
# Calcium dependent subgraph                            793         0.008724
# Chromatin organization subgraph                        10         0.178571
# Energy metabolic subgraph                             177         0.021612
# Estradiol metabolism                                    8         0.190476
# G-protein-mediated signaling                          140         0.023310
# Gaba subgraph                                         632         0.009242
# Glutamatergic subgraph                                246         0.016942
# Hormone signaling subgraph                            256         0.016254
# Inflammatory response subgraph                         49         0.028455
# Innate immune system subgraph                          63         0.038415
# Interleukin signaling subgraph                        111         0.053623
# Long term synaptic depression                         129         0.031994
# Long term synaptic potentiation                       252         0.016258
# Mapk-erk subgraph                                     706         0.007229
# Metabolism                                            600         0.005206
# Mirna subgraph                                          4         0.200000
# Mossy fiber subgraph                                   66         0.046942
# Mtor signaling subgraph                               336         0.012267
# Neurotransmitter release subgraph                    1667         0.005481
# Notch signaling subgraph                              205         0.018773
# Protein kinase signaling subgraph                     850         0.005996
# Protein metabolism                                    185         0.011204
# Reelin signaling subgraph                             253         0.018641
# Regulation of actin cytoskeleton subgraph               3         0.150000
# Serotonergic subgraph                                 478         0.021971
# Thyroid hormone signaling subgraph                    228         0.020485
# Transport related subgraph                             60         0.025510
# Wnt signaling subgraph                                 38         0.054131
# Total                                               12481         0.001032
#
#                                                     Nodes
# Adaptive immune system subgraph                        12
# Adenosine signaling subgraph                           76
# Apoptosis signaling subgraph                          228
# Brain_derived neurotrophic factor signaling sub...     75
# Calcium dependent subgraph                            302
# Chromatin organization subgraph                         8
# Energy metabolic subgraph                              91
# Estradiol metabolism                                    7
# G-protein-mediated signaling                           78
# Gaba subgraph                                         262
# Glutamatergic subgraph                                121
# Hormone signaling subgraph                            126
# Inflammatory response subgraph                         42
# Innate immune system subgraph                          41
# Interleukin signaling subgraph                         46
# Long term synaptic depression                          64
# Long term synaptic potentiation                       125
# Mapk-erk subgraph                                     313
# Metabolism                                            340
# Mirna subgraph                                          5
# Mossy fiber subgraph                                   38
# Mtor signaling subgraph                               166
# Neurotransmitter release subgraph                     552
# Notch signaling subgraph                              105
# Protein kinase signaling subgraph                     377
# Protein metabolism                                    129
# Reelin signaling subgraph                             117
# Regulation of actin cytoskeleton subgraph               5
# Serotonergic subgraph                                 148
# Thyroid hormone signaling subgraph                    106
# Transport related subgraph                             49
# Wnt signaling subgraph                                 27
# Total                                                3478

# %% [markdown]
# The dataframe can be output to CSV, or a wide variety of other formats using pandas.

# %%
path = os.path.join(os.path.expanduser("~"), "Desktop", "subgraph_summary.vcsv")
df[["Nodes", "Edges", "Components", "Citations"]].to_csv(path)
