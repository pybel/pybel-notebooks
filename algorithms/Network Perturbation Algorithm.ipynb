# %% [markdown]
# # Abstract
#
# **Author:** [Charles Tapley Hoyt](https://github.com/cthoyt)
#
# **Estimated Run Time:** 4 minutes
#
# This notebooks demonstrates the usage of a variant on the [Network Perturbation Amplitude](http://bmcsystbiol.biomedcentral.com/articles/10.1186/1752-0509-6-54) algorithm to analyze an BEL knowledge assembly in the context of a differential gene expression experiment.

# %% [markdown]
# ### Notebook Imports

# %%
import logging
import os
import time

import pandas as pd
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from matplotlib_venn import venn2

import pybel
import pybel_tools as pbt
import pybel_tools.analysis.npa as npa
from pybel.constants import *
from pybel.canonicalize import calculate_canonical_name
from pybel_tools.visualization import to_jupyter

# %%
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# ### Notebook Provenance
#
# The time of execution, random number generator seed, and the versions of the software packages used are displayed explicitly.

# %%
time.asctime()
# Out:
# 'Tue Apr 25 11:17:04 2017'

# %%
# seed the random number generator
import random
random.seed(127)

# %%
pybel.__version__
# Out:
# '0.5.4-dev'

# %%
pbt.__version__
# Out:
# '0.1.8-dev'

# %% [markdown]
# ### Local Path Definitions
#
# To make this notebook interoperable across many machines, locations to the repositories that contain the data used in this notebook are referenced from the environment, set in `~/.bashrc` to point to the place where the repositories have been cloned. Assuming the repositories have been `git clone`'d into the `~/dev` folder, the entries in `~/.bashrc` should look like:
#
# ```bash
# ...
# export BMS_BASE=~/dev/bms
# ...
# ```
#
# #### BMS
#
# The biological model store (BMS) is the internal Fraunhofer SCAI repository for keeping BEL models under version control. It can be downloaded from https://tor-2.scai.fraunhofer.de/gf/project/bms/

# %%
bms_base = os.environ['BMS_BASE']

# %% [markdown]
# #### OwnCloud
#
# The differential gene expression data used in this notebook is currently not published, and is obfuscated with reference through our team's internal data storage system with [OwnCloud](https://owncloud.org/).

# %%
owncloud_base = os.environ['OWNCLOUD_BASE']

# %% [markdown]
# # Data
#
# ## Alzheimer's Disease Knowledge Assembly
#
# The Alzheimer's Disease Knowledge Assembly has been precompiled with the following command line script, and will be loaded from this format for improved performance. In general, derived data, such as the gpickle representation of a BEL script, are not saved under version control to ensure that the most up-to-date data is always used.
#
# ```sh
# pybel convert --path "$BMS_BASE/aetionomy/alzheimers.bel" --pickle "$BMS_BASE/aetionomy/alzheimers.gpickle"
# ```
#
# The BEL script can also be compiled from inside this notebook with the following python code:
#
# ```python
# >>> import os
# >>> import pybel
# >>> # Input from BEL script
# >>> bel_path = os.path.join(bms_base, 'aetionomy', 'alzheimers.bel')
# >>> graph = pybel.from_path(bel_path)
# >>> # Output to gpickle for fast loading later
# >>> pickle_path = os.path.join(bms_base, 'aetionomy', 'alzheimers.gpickle')
# >>> pybel.to_pickle(graph, pickle_path)
# ```

# %%
pickle_path = os.path.join(bms_base, 'aetionomy', 'alzheimers', 'alzheimers.gpickle')

# %%
graph = pybel.from_pickle(pickle_path)

# %%
graph.version
# Out:
# '3.0.2'

# %% [markdown]
# All orthologies are discared before analysis.

# %%
pbt.filters.remove_nodes_by_namespace(graph, 'MGI')
pbt.filters.remove_nodes_by_namespace(graph, 'RGD')

# %% [markdown]
# To merge the differential gene expression annotations, the entire graph is collapsed to genes using [pbt.mutation.collapse_by_central_dogma_to_genes](http://pybel-tools.readthedocs.io/en/latest/mutation.html#pybel_tools.mutation.collapse_by_central_dogma_to_genes)

# %%
pbt.mutation.opening_on_central_dogma(graph)

pbt.mutation.collapse_variants_to_genes(graph)

# %%
pbt.summary.print_summary(graph)
# Out:
# Number of nodes: 4071
# Number of edges: 19726
# Network density: 0.0011905386997501956
# Number weakly connected components: 75
# Average in-degree: 4.8454925079832964
# Average out-degree: 4.8454925079832964

# %%
pbt.summary.plot_summary(graph, plt, figsize=(10, 4))
plt.show()

# %% [markdown]
# ## Differential Gene Expression
#
# Differential gene expression data can be obtained from many sources, including ADNI and other large clinical studies. This analysis is concerned with the log-fold-changes on each gene, and not necessarily the p-value. This is better as a data-driven process becuase it does not require a model or multiple hypothesis testing on raw data.

# %%
data_path = os.path.join(owncloud_base, 'SevAD.csv')
target_columns = ['Gene.symbol', 'logFC']

# %%
df = pd.read_csv(data_path)
df = df.loc[df['Gene.symbol'].notnull(), target_columns]
df.head()
# Out:
#   Gene.symbol     logFC
# 0      ZNF616 -4.244691
# 1     DEFB125  3.974393
# 3      SNAP23  3.337636
# 4      PHLDB2  3.192559
# 5   LOC389895 -4.296850

# %% [markdown]
# A histogram of the log-fold-changes shows that the data are normally distributed, as expected for differential gene expression data.

# %%
# max_fc = {}
# for row, symbol, fc in df.itertuples():
#    if symbol not in max_fc or abs(max_fc[symbol]) < abs(fc):
#        max_fc[symbol] = fc
        
data = {k: v for _, k, v in df.itertuples()}

# %%
plt.title('Distribution of Log-Fold-Changes')
plt.xlabel('Log-Fold-Change')
plt.ylabel('Frequency')
plt.hist(list(data.values()))
plt.show()

# %% [markdown]
# ## Overlap Summary

# %% [markdown]
# The number of shared elements in the knowledge assembly and differential gene data set are counted.

# %%
hgnc_names = pbt.summary.get_names(graph, 'HGNC')
df_names = set(df['Gene.symbol'])
overlapping_hgnc_names = hgnc_names & df_names

plt.title('HGNC Gene Names')
venn2([hgnc_names, df_names], set_labels=["Alzheimer's Disease KAM", 'E-GEOD-5281'])
plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Data Integration
#
# Finally, the differential gene expression data are ovelayed on the BEL graph with [pbt.integration.overlay_type_data](http://pybel-tools.readthedocs.io/en/latest/integration.html#pybel_tools.integration.overlay_type_data)

# %%
label = 'weight'

# %%
pbt.integration.overlay_type_data(graph, data, label, GENE, 'HGNC', overwrite=False, impute=0)

# %% [markdown]
# ## Subgraph Generation
#
# A subgraph is induced around an example biological process, Inflammatory Response, by selecting all of the source nodes of upstream causal edges, where this process is the target node. These networks are then enriched by expandind around all of those nodes' upstream edges as well.

# %%
inflamation_node = BIOPROCESS, 'GOBP', 'inflammatory response'

# %% [markdown]
# ### Iteration 1/2
#
# All of the nodes that have upstream causal relations to Inflammatory Response are added.

# %%
subgraph = pbt.mutation.get_upstream_causal_subgraph(graph, inflamation_node)

pbt.summary.print_summary(subgraph)
to_jupyter(subgraph)
# Out:
# Number of nodes: 32
# Number of edges: 53
# Network density: 0.05342741935483871
# Number weakly connected components: 1
# Average in-degree: 1.65625
# Average out-degree: 1.65625

# %% [markdown]
# ### Iteration 2/2
#
# All of the nodes upstream of the nodes within the subgraph are added as well.

# %%
pbt.mutation.expand_upstream_causal_subgraph(graph, subgraph)
pbt.summary.print_summary(subgraph)
# Out:
# Number of nodes: 266
# Number of edges: 1081
# Network density: 0.015335508582777699
# Number weakly connected components: 1
# Average in-degree: 4.06390977443609
# Average out-degree: 4.06390977443609

# %% [markdown]
# ### Post-Processing
#
# Inconsistient edges are thrown away, literature bias is removed, and nodes on the periphery of the subgraph that are not annotated with experimental data are also removed, since they cannot contribute to the propogation of scores.

# %%
pbt.mutation.remove_inconsistent_edges(graph)

# %%
pbt.mutation.collapse_consistent_edges(graph)

# %%
pbt.generation.remove_unweighted_leaves(subgraph, label)

# %%
pbt.generation.remove_unweighted_sources(subgraph, label)

# %%
pbt.summary.print_summary(subgraph)
to_jupyter(subgraph)
# Out:
# Number of nodes: 51
# Number of edges: 132
# Network density: 0.05176470588235294
# Number weakly connected components: 1
# Average in-degree: 2.588235294117647
# Average out-degree: 2.588235294117647

# %% [markdown]
# This entire procedure can be run automatically with [pbt.generation.generate_mechanism](http://pybel-tools.readthedocs.io/en/latest/generation.html#pybel_tools.generation.generate_mechanism)

# %% [markdown]
# ## Running

# %%
runner = npa.NpaRunner(subgraph, inflamation_node, label)

# %% [markdown]
# While the algorithm can be immediately run with [pbt.analysis.npa.NpaRunner.run](http://pybel-tools.readthedocs.io/en/latest/npa.html#pybel_tools.analysis.npa.NpaRunner.run), the process is outlined to show the evolution of the graph throughouts its steps. For animation purposes, the functin [pbt.analysis.npa.NpaRunner.run_with_graph_transformation](http://pybel-tools.readthedocs.io/en/latest/npa.html#pybel_tools.analysis.npa.NpaRunner.run_with_graph_transformation) yields a new `BELGraph` at each step through the process as well.

# %%
runner.score_leaves()
# Out:
# {('Abundance', 'MESHCS', 'Neurofibrillary Tangles'),
#  ('Protein', 'HGNC', 'CX3CR1'),
#  ('Protein', 'HGNC', 'IL12B')}

# %%
to_jupyter(runner.get_remaining_graph(), height=400)

# %%
runner.score_leaves()
# Out:
# WARNING:pybel_tools.analysis.npa:no leaves.
# set()

# %%
to_jupyter(runner.get_remaining_graph(), height=400)

# %%
runner.score_leaves()
# Out:
# WARNING:pybel_tools.analysis.npa:no leaves.
# set()

# %%
runner.remove_random_edge()

to_jupyter(runner.get_remaining_graph(), height=400)

# %%
runner.score_leaves()
# Out:
# {('Protein', 'HGNC', 'SCARB1')}

# %%
runner.score_leaves()
# Out:
# WARNING:pybel_tools.analysis.npa:no leaves.
# set()

# %%
runner.remove_random_edge()
leaves = runner.score_leaves()
len(leaves)
# Out:
# 1

# %%
to_jupyter(runner.get_remaining_graph(), height=400)

# %%
runner.run()

# %%
runner.get_final_score()
# Out:
# 5.6699960399999956

# %% [markdown]
# ## Robustness Analysis
#
# The algorithm is random, so it can be run multiple times to assess the robustness of the final scores using [pbt.analysis.npa.multirun](http://pybel-tools.readthedocs.io/en/latest/npa.html#pybel_tools.analysis.npa.multirun)

# %%
# %%time

runners = list(npa.multirun(subgraph, inflamation_node, label, default_score=0, runs=500))
# Out:
# CPU times: user 7.59 s, sys: 77.7 ms, total: 7.66 s
# Wall time: 7.69 s

# %%
plt.title('Histogram of NPA scores for {}'.format(calculate_canonical_name(subgraph, inflamation_node)))
plt.ylabel('Frequency')
plt.xlabel('Score')
plt.hist([runner.get_final_score() for runner in runners])
plt.show()

# %% [markdown]
# ## Full Workflow
#
# This workflow can all be run with [pbt.analysis.npa.workflow_all_average](http://pybel-tools.readthedocs.io/en/latest/npa.html#pybel_tools.analysis.npa.workflow_all_average) but is outlined here for a deeper understanding.
#
# ### Generate Candidate Mechanisms
#
# Candidate mechanism are generated with the aforementioned function [pbt.generation.generate_mechanism](http://pybel-tools.readthedocs.io/en/latest/generation.html#pybel_tools.generation.generate_mechanism) to assess the upstream causal subgraphs of all biological processes.

# %%
all_bioprocesses = pbt.filters.get_nodes_by_function(graph, BIOPROCESS)

# %%
# %%time

candidate_mechanisms = {node: pbt.generation.generate_mechanism(graph, node, label) for node in all_bioprocesses}
# Out:
# CPU times: user 1.88 s, sys: 20.1 ms, total: 1.9 s
# Wall time: 1.91 s

# %% [markdown]
# The algorithm is run over all candidate subgraphs that are nontrivial (have more than one node in them) and a pandas DataFrame is prepared.

# %%
# %%time

scores = {}

for node, subgraph in candidate_mechanisms.items():
    
    fneighbors = subgraph.in_degree(node)
    fneighbors = 0 if isinstance(fneighbors, dict) else fneighbors
    size = subgraph.number_of_nodes()
    
    if size <= 1:  # Can't calculate a score for empty subgraphs
        average_score = None
    else:
        average_score = npa.workflow_average(subgraph, node, label, runs=40)
    
    scores[node] = (average_score, fneighbors, size)
# Out:
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'endoplasmic reticulum calcium ion homeostasis')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'neuron migration')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'endocytosis')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'synaptic vesicle budding from endosome')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'positive regulation of mitochondrial membrane potential')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'cellular senescence')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'synaptic transmission, cholinergic')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'xenobiotic metabolic process')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'rhythmic excitation')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'phagocytosis, engulfment')
# WARNING:pybel_tools.analysis.npa:Unable to run NPA on ('BiologicalProcess', 'GOBP', 'regulation of dendritic cell antigen processing and presentation')
# CPU times: user 10.8 s, sys: 81.8 ms, total: 10.9 s
# Wall time: 10.9 s

# %%
len(candidate_mechanisms), sum(1 for score, _, _ in scores.values() if score)
# Out:
# (430, 139)

# %%
# Optionally, calcualte "cute names" for the nodes
# scores = {calculate_canonical_name(graph, n): s for n, s in scores.items()}

scores_df = pd.DataFrame.from_items(scores.items(), orient='index', columns=['Average NPA Score','Number First Neighbors','Subgraph Size'])

# %% [markdown]
# A scatter matrix is shown below. The distribution of average NPA scores is shown to be mostly normal. The following scatter plots show small, non-linear relationships between average NPA score and the subgraph size and the number of first neighbors of the seed node. The trivial positive correlation between number of first neighbors is also shown.

# %%
scatter_matrix(scores_df[scores_df['Average NPA Score'].notnull()], figsize=(10, 7))
plt.show()

# %%
scores_df.to_csv(os.path.expanduser('~/Desktop/npa_demo.csv'))

# %%
scores_df[scores_df['Average NPA Score'].notnull()].sort_values('Average NPA Score')
# Out:
#                                                     Average NPA Score  \
# (BiologicalProcess, GOBP, cognition)                        -1.957483
# (BiologicalProcess, GOBP, regulation of glucose...          -1.773353
# (BiologicalProcess, GOBP, central nervous syste...          -1.516629
# (BiologicalProcess, MESHPP, Unfolded Protein Re...          -1.515212
# (BiologicalProcess, GOBP, protein import into m...          -1.163541
# (BiologicalProcess, GOBP, mitochondrial calcium...          -1.090722
# (BiologicalProcess, GOBP, electron transport ch...          -1.007132
# (BiologicalProcess, GOBP, memory)                           -0.998019
# (BiologicalProcess, GOBP, regulation of catalyt...          -0.910587
# (BiologicalProcess, GOBP, signaling)                        -0.884248
# (BiologicalProcess, GOBP, regulation of cellula...          -0.874394
# (BiologicalProcess, GOBP, positive regulation o...          -0.725764
# (BiologicalProcess, GOBP, production of molecul...          -0.725035
# (BiologicalProcess, GOBP, positive regulation o...          -0.720539
# (BiologicalProcess, GOBP, apoptotic process)                -0.630201
# (BiologicalProcess, GOBP, negative regulation o...          -0.567215
# (BiologicalProcess, PTS, inflammatory response ...          -0.567215
# (BiologicalProcess, GOBP, plasma membrane fusion)           -0.492646
# (BiologicalProcess, GOBP, regulation of cAMP-de...          -0.488954
# (BiologicalProcess, GOBP, apoptotic signaling p...          -0.479993
# (BiologicalProcess, GOBP, microglial cell activ...          -0.462424
# (BiologicalProcess, PMIBP, ST6GAL1 secretion)               -0.416736
# (BiologicalProcess, GOBP, regulation of neurona...          -0.415490
# (BiologicalProcess, GOBP, cytokine production)              -0.401348
# (BiologicalProcess, GOBP, negative regulation o...          -0.401348
# (BiologicalProcess, GOBP, chemokine biosyntheti...          -0.401348
# (BiologicalProcess, GOBP, cytokine secretion)               -0.401348
# (BiologicalProcess, GOBP, positive regulation o...          -0.390744
# (BiologicalProcess, GOBP, positive regulation o...          -0.390744
# (BiologicalProcess, GOBP, microglial cell activ...          -0.274029
# ...                                                               ...
# (BiologicalProcess, GOBP, zinc ion homeostasis)              0.557388
# (BiologicalProcess, GOBP, leukocyte mediated im...           0.557388
# (BiologicalProcess, GOBP, negative regulation o...           0.557388
# (BiologicalProcess, GOBP, cAMP-mediated signaling)           0.557388
# (BiologicalProcess, GOBP, growth)                            0.594557
# (BiologicalProcess, GOBP, mitochondria-nucleus ...           0.595800
# (BiologicalProcess, GOBP, DNA biosynthetic proc...           0.845759
# (BiologicalProcess, GOBP, RNA metabolic process)             0.858920
# (BiologicalProcess, GOBP, cell migration)                    0.935996
# (BiologicalProcess, GOBP, brain development)                 0.980261
# (BiologicalProcess, GOBP, synaptic transmission...           0.991187
# (BiologicalProcess, GOBP, regulation of growth)              0.998013
# (BiologicalProcess, GOBP, reactive oxygen speci...           1.000978
# (BiologicalProcess, GOBP, cell-cell signaling)               1.004358
# (BiologicalProcess, GOBP, calcium ion import)                1.007735
# (BiologicalProcess, GOBP, cell adhesion)                     1.027519
# (BiologicalProcess, GOBP, cholesterol biosynthe...           1.045284
# (BiologicalProcess, GOBP, synapse assembly)                  1.048500
# (BiologicalProcess, GOBP, stress-activated prot...           1.060898
# (BiologicalProcess, GOBP, cell-matrix adhesion)              1.094275
# (BiologicalProcess, MESHPP, Insulin Resistance)              1.157408
# (BiologicalProcess, GOBP, cell death)                        1.250924
# (BiologicalProcess, GOBP, mitochondrion organiz...           1.493461
# (BiologicalProcess, GOBP, inflammatory response)             1.519586
# (BiologicalProcess, GOBP, neuron apoptotic proc...           1.907206
# (BiologicalProcess, GOBP, neuron death)                      2.108491
# (BiologicalProcess, GOBP, energy reserve metabo...           2.940783
# (BiologicalProcess, GOBP, glucose metabolic pro...           2.940783
# (BiologicalProcess, GOBP, negative regulation o...           2.982289
# (BiologicalProcess, GOBP, glial cell differenti...           4.136399
#
#                                                     Number First Neighbors  \
# (BiologicalProcess, GOBP, cognition)                                    18
# (BiologicalProcess, GOBP, regulation of glucose...                       2
# (BiologicalProcess, GOBP, central nervous syste...                       2
# (BiologicalProcess, MESHPP, Unfolded Protein Re...                       1
# (BiologicalProcess, GOBP, protein import into m...                       2
# (BiologicalProcess, GOBP, mitochondrial calcium...                       2
# (BiologicalProcess, GOBP, electron transport ch...                       2
# (BiologicalProcess, GOBP, memory)                                       17
# (BiologicalProcess, GOBP, regulation of catalyt...                       3
# (BiologicalProcess, GOBP, signaling)                                     2
# (BiologicalProcess, GOBP, regulation of cellula...                       1
# (BiologicalProcess, GOBP, positive regulation o...                       3
# (BiologicalProcess, GOBP, production of molecul...                       8
# (BiologicalProcess, GOBP, positive regulation o...                       1
# (BiologicalProcess, GOBP, apoptotic process)                            35
# (BiologicalProcess, GOBP, negative regulation o...                       1
# (BiologicalProcess, PTS, inflammatory response ...                       1
# (BiologicalProcess, GOBP, plasma membrane fusion)                        1
# (BiologicalProcess, GOBP, regulation of cAMP-de...                       1
# (BiologicalProcess, GOBP, apoptotic signaling p...                       1
# (BiologicalProcess, GOBP, microglial cell activ...                       4
# (BiologicalProcess, PMIBP, ST6GAL1 secretion)                            1
# (BiologicalProcess, GOBP, regulation of neurona...                       2
# (BiologicalProcess, GOBP, cytokine production)                           1
# (BiologicalProcess, GOBP, negative regulation o...                       1
# (BiologicalProcess, GOBP, chemokine biosyntheti...                       2
# (BiologicalProcess, GOBP, cytokine secretion)                            1
# (BiologicalProcess, GOBP, positive regulation o...                       1
# (BiologicalProcess, GOBP, positive regulation o...                       1
# (BiologicalProcess, GOBP, microglial cell activ...                       3
# ...                                                                    ...
# (BiologicalProcess, GOBP, zinc ion homeostasis)                          1
# (BiologicalProcess, GOBP, leukocyte mediated im...                       1
# (BiologicalProcess, GOBP, negative regulation o...                       1
# (BiologicalProcess, GOBP, cAMP-mediated signaling)                       1
# (BiologicalProcess, GOBP, growth)                                        1
# (BiologicalProcess, GOBP, mitochondria-nucleus ...                       4
# (BiologicalProcess, GOBP, DNA biosynthetic proc...                       2
# (BiologicalProcess, GOBP, RNA metabolic process)                         1
# (BiologicalProcess, GOBP, cell migration)                                1
# (BiologicalProcess, GOBP, brain development)                             1
# (BiologicalProcess, GOBP, synaptic transmission...                       1
# (BiologicalProcess, GOBP, regulation of growth)                          1
# (BiologicalProcess, GOBP, reactive oxygen speci...                       2
# (BiologicalProcess, GOBP, cell-cell signaling)                           1
# (BiologicalProcess, GOBP, calcium ion import)                           13
# (BiologicalProcess, GOBP, cell adhesion)                                 1
# (BiologicalProcess, GOBP, cholesterol biosynthe...                       1
# (BiologicalProcess, GOBP, synapse assembly)                              1
# (BiologicalProcess, GOBP, stress-activated prot...                       2
# (BiologicalProcess, GOBP, cell-matrix adhesion)                          3
# (BiologicalProcess, MESHPP, Insulin Resistance)                          6
# (BiologicalProcess, GOBP, cell death)                                   11
# (BiologicalProcess, GOBP, mitochondrion organiz...                       5
# (BiologicalProcess, GOBP, inflammatory response)                        14
# (BiologicalProcess, GOBP, neuron apoptotic proc...                      30
# (BiologicalProcess, GOBP, neuron death)                                 13
# (BiologicalProcess, GOBP, energy reserve metabo...                       3
# (BiologicalProcess, GOBP, glucose metabolic pro...                       3
# (BiologicalProcess, GOBP, negative regulation o...                       6
# (BiologicalProcess, GOBP, glial cell differenti...                       6
#
#                                                     Subgraph Size
# (BiologicalProcess, GOBP, cognition)                           49
# (BiologicalProcess, GOBP, regulation of glucose...              5
# (BiologicalProcess, GOBP, central nervous syste...              5
# (BiologicalProcess, MESHPP, Unfolded Protein Re...              3
# (BiologicalProcess, GOBP, protein import into m...             34
# (BiologicalProcess, GOBP, mitochondrial calcium...             34
# (BiologicalProcess, GOBP, electron transport ch...             34
# (BiologicalProcess, GOBP, memory)                              55
# (BiologicalProcess, GOBP, regulation of catalyt...             14
# (BiologicalProcess, GOBP, signaling)                            3
# (BiologicalProcess, GOBP, regulation of cellula...              9
# (BiologicalProcess, GOBP, positive regulation o...              4
# (BiologicalProcess, GOBP, production of molecul...             15
# (BiologicalProcess, GOBP, positive regulation o...              3
# (BiologicalProcess, GOBP, apoptotic process)                   51
# (BiologicalProcess, GOBP, negative regulation o...              7
# (BiologicalProcess, PTS, inflammatory response ...              7
# (BiologicalProcess, GOBP, plasma membrane fusion)               2
# (BiologicalProcess, GOBP, regulation of cAMP-de...              2
# (BiologicalProcess, GOBP, apoptotic signaling p...              4
# (BiologicalProcess, GOBP, microglial cell activ...              6
# (BiologicalProcess, PMIBP, ST6GAL1 secretion)                   8
# (BiologicalProcess, GOBP, regulation of neurona...              5
# (BiologicalProcess, GOBP, cytokine production)                  3
# (BiologicalProcess, GOBP, negative regulation o...              2
# (BiologicalProcess, GOBP, chemokine biosyntheti...              4
# (BiologicalProcess, GOBP, cytokine secretion)                   3
# (BiologicalProcess, GOBP, positive regulation o...              3
# (BiologicalProcess, GOBP, positive regulation o...              3
# (BiologicalProcess, GOBP, microglial cell activ...              5
# ...                                                           ...
# (BiologicalProcess, GOBP, zinc ion homeostasis)                31
# (BiologicalProcess, GOBP, leukocyte mediated im...             31
# (BiologicalProcess, GOBP, negative regulation o...             31
# (BiologicalProcess, GOBP, cAMP-mediated signaling)             31
# (BiologicalProcess, GOBP, growth)                               9
# (BiologicalProcess, GOBP, mitochondria-nucleus ...             55
# (BiologicalProcess, GOBP, DNA biosynthetic proc...             11
# (BiologicalProcess, GOBP, RNA metabolic process)                9
# (BiologicalProcess, GOBP, cell migration)                       9
# (BiologicalProcess, GOBP, brain development)                    3
# (BiologicalProcess, GOBP, synaptic transmission...              9
# (BiologicalProcess, GOBP, regulation of growth)                 9
# (BiologicalProcess, GOBP, reactive oxygen speci...             34
# (BiologicalProcess, GOBP, cell-cell signaling)                  9
# (BiologicalProcess, GOBP, calcium ion import)                  17
# (BiologicalProcess, GOBP, cell adhesion)                        9
# (BiologicalProcess, GOBP, cholesterol biosynthe...              3
# (BiologicalProcess, GOBP, synapse assembly)                     9
# (BiologicalProcess, GOBP, stress-activated prot...             10
# (BiologicalProcess, GOBP, cell-matrix adhesion)                11
# (BiologicalProcess, MESHPP, Insulin Resistance)                12
# (BiologicalProcess, GOBP, cell death)                          39
# (BiologicalProcess, GOBP, mitochondrion organiz...             56
# (BiologicalProcess, GOBP, inflammatory response)               47
# (BiologicalProcess, GOBP, neuron apoptotic proc...             69
# (BiologicalProcess, GOBP, neuron death)                        27
# (BiologicalProcess, GOBP, energy reserve metabo...              5
# (BiologicalProcess, GOBP, glucose metabolic pro...              5
# (BiologicalProcess, GOBP, negative regulation o...             13
# (BiologicalProcess, GOBP, glial cell differenti...             14
#
# [141 rows x 3 columns]

# %% [markdown]
# # Conclusions
#
# ## Problems
#
# This algorithm overcomes deterministic problems with cyclic graphs by randomly removing edges. It can be run multiple times to assess the stability of the score with `pbt.analysis.npa.average_npa_run`. The effect of the default score can also be checked with a grid search.
#
# ## Looking Forward
#
# While this new algorithm is generally applicable and overcomes the original algorithm, it must throw away information to do so. Further algorithmic development, such as heat diffusion approaches could allow for a more thorough investigation of the propogation of effects of the differential gene expression.
#
# This algorithm can be run over the mechanisms generated for each biological process. Further investigation into the upstream mechanism generation can yield bias-free candidate mechanisms. They can also be matched to canonical mechanisms in NeuroMMSigDB to identify concordance between the biological dogma and all possible mechanisms, then to identify previously unknown cross-talk between mechanisms.
